# %% [markdown]
# # TASK<a href="#TASK" class="anchor-link">¶</a>
#
# -   Download the rough **Hepatitis** dataset from the [UCI Machine
#     Learning
#     Repository](https://archive.ics.uci.edu/ml/datasets/hepatitis)
# -   Load the dataset (*hepatitis.data*) in Python (using the correct
#     names for the variables as described in the *hepatitis.name* file)
# -   Handle missing values
# -   Save the final dataset in the .csv format

# %%
import pandas as pd
import os

# %%
columns = ['Class',
                'AGE',
                'SEX',
                'STEROID',
                'ANTIVIRALS',
                'FATIGUE',
                'MALAISE',
                'ANOREXIA',
                'LIVER BIG',
                'LIVER FIRM',
                'SPLEEN PALPABLE',
                'SPIDERS',
                'ASCITES',
                'VARICES',
                'BILIRUBIN',
                'ALK PHOSPHATE',
                'SGOT',
                'ALBUMIN',
                'PROTIME',
                'HISTOLOGY']

# %%
df = pd.read_csv('/Users/marysia/Downloads/hepatitis.csv',names = columns, na_values = '?')
df
# Out:
#     Class  AGE  SEX  STEROID  ANTIVIRALS  FATIGUE  MALAISE  ANOREXIA  \
# 0   Class  AGE  SEX  STEROID  ANTIVIRALS  FATIGUE  MALAISE  ANOREXIA
# 1       2   34    1      2.0           2      2.0      2.0       2.0
# 2       2   39    1      1.0           1      2.0      2.0       2.0
# 3       2   32    1      2.0           1      1.0      2.0       2.0
# 4       2   41    1      2.0           1      1.0      2.0       2.0
# ..    ...  ...  ...      ...         ...      ...      ...       ...
# 76      2   45    1      2.0           1      2.0      2.0       2.0
# 77      1   49    1      1.0           2      1.0      1.0       2.0
# 78      2   31    1      1.0           2      1.0      2.0       2.0
# 79      2   53    2      1.0           2      1.0      2.0       2.0
# 80      1   43    1      2.0           2      1.0      2.0       2.0
#
#     LIVER BIG  LIVER FIRM  SPLEEN PALPABLE  SPIDERS  ASCITES  VARICES  \
# ...

# %%
for col in df.columns:
    display(df[col].value_counts())
# Out:
# Class
# 2        67
# 1        13
# Class     1
# Name: count, dtype: int64
# AGE
# 38     7
# 30     5
# 34     4
# 32     4
# 50     4
# 39     3
# 47     3
# 40     3
# 27     3
# 54     3
# 42     3
# 36     3
# 51     2
# 28     2
# 31     2
# 49     2
# 25     2
# 33     2
# 41     2
# 59     1
# AGE    1
# 72     1
# 48     1
# 20     1
# 57     1
# 45     1
# 53     1
# 62     1
# 52     1
# 37     1
# 64     1
# 44     1
# 56     1
# 65     1
# 23     1
# 35     1
# 26     1
# 61     1
# 58     1
# 22     1
# 43     1
# Name: count, dtype: int64
# SEX
# 1      69
# 2      11
# SEX     1
# Name: count, dtype: int64
# STEROID
# 2.0        42
# 1.0        38
# STEROID     1
# Name: count, dtype: int64
# ANTIVIRALS
# 2             59
# 1             21
# ANTIVIRALS     1
# Name: count, dtype: int64
# FATIGUE
# 1.0        52
# 2.0        28
# FATIGUE     1
# Name: count, dtype: int64
# MALAISE
# 2.0        49
# 1.0        31
# MALAISE     1
# Name: count, dtype: int64
# ANOREXIA
# ...

# %%
df.isna().sum(axis=0)
# Out:
# Class              0
# AGE                0
# SEX                0
# STEROID            0
# ANTIVIRALS         0
# FATIGUE            0
# MALAISE            0
# ANOREXIA           0
# LIVER BIG          0
# LIVER FIRM         0
# SPLEEN PALPABLE    0
# SPIDERS            0
# ASCITES            0
# VARICES            0
# BILIRUBIN          0
# ALK PHOSPHATE      0
# SGOT               0
# ALBUMIN            0
# PROTIME            0
# HISTOLOGY          0
# dtype: int64

# %%
# ignoring tuples, just as an example: in this way too much information is discarded (almost half of the dataset)

# %%
df_notna = df.dropna(how='any')
df_notna
# Out:
#     Class  AGE  SEX  STEROID  ANTIVIRALS  FATIGUE  MALAISE  ANOREXIA  \
# 0   Class  AGE  SEX  STEROID  ANTIVIRALS  FATIGUE  MALAISE  ANOREXIA
# 1       2   34    1      2.0           2      2.0      2.0       2.0
# 2       2   39    1      1.0           1      2.0      2.0       2.0
# 3       2   32    1      2.0           1      1.0      2.0       2.0
# 4       2   41    1      2.0           1      1.0      2.0       2.0
# ..    ...  ...  ...      ...         ...      ...      ...       ...
# 76      2   45    1      2.0           1      2.0      2.0       2.0
# 77      1   49    1      1.0           2      1.0      1.0       2.0
# 78      2   31    1      1.0           2      1.0      2.0       2.0
# 79      2   53    2      1.0           2      1.0      2.0       2.0
# 80      1   43    1      2.0           2      1.0      2.0       2.0
#
#     LIVER BIG  LIVER FIRM  SPLEEN PALPABLE  SPIDERS  ASCITES  VARICES  \
# ...

# %%
df_notna.to_csv(os.path.join('dataset','hepatitis.csv'),index = None)
